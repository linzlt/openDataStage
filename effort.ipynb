# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

def creer_repertoire(chemin):
    if not os.path.exists(chemin):
        os.makedirs(chemin)

def charger_donnees(nom_fichier):
    try:
        return pd.read_csv(nom_fichier, delimiter=";", skiprows=0)
    except FileNotFoundError:
        print(f"FileNotFoundError: {nom_fichier} n'a pas été trouvé.")
        return None

def convertir_colonnes_en_float(df):
    for col in df.columns:
        if df[col].dtype == "object":
            df[col] = df[col].str.replace(",", ".").astype(float)
        elif df[col].dtype == "float64" and df[col].isnull().any():
            df[col] = df[col].astype(float)
    return df

def tracer_et_sauvegarder_graphique(col_x, col_y, essai, chemin_figures):
    plt.plot(col_x, col_y, label=f'Essai {essai}')
    plt.title(f"Essai {essai}")
    plt.xlabel("Déplacement ") # Ajouter l'unité du déplacement
    plt.ylabel("Effort") # Ajouter l'unité de l'effort 
    plt.legend(loc="upper right")
    plt.grid(True)
    nom_figure = os.path.join(chemin_figures, f"ESSAI_{str(essai).zfill(3)}.png")
    plt.savefig(nom_figure)
    plt.close()

def traiter_fichier(df, essai, chemin_figures):
    df = convertir_colonnes_en_float(df)
    if df.shape[1] > 8:
        df.iloc[:, 8] -= df.iloc[0, 8]
        col_x, col_y = df.iloc[:, 0], df.iloc[:, 8]
    elif df.shape[1] < 5:
        col_x, col_y = df.iloc[:, 0], df.iloc[:, 3]
    else:
        print(f"Le fichier ESSAI_{str(essai).zfill(3)}.csv n'a pas assez de colonnes.")
        return

    dernier_index_non_nan = min(col_x.last_valid_index(), col_y.last_valid_index())
    tracer_et_sauvegarder_graphique(col_x[:dernier_index_non_nan + 1], col_y[:dernier_index_non_nan + 1], essai, chemin_figures)
def traiter_essai_a_vide(nom_fichier, essai, chemin_figures):
    df = charger_donnees(nom_fichier)
    if df is not None : 
        df = convertir_colonnes_en_float(df)
        if df.shape[1] > 8:
            df.iloc[:, 8] -= df.iloc[0, 8]
            col_x, col_y = df.iloc[:, 0], df.iloc[:, 8]
        elif df.shape[1] < 5:
            col_x, col_y = df.iloc[:, 0], df.iloc[:, 3]
        else:
            print(f"Le fichier {nom_fichier} n'a pas assez de colonnes.")
            return

        dernier_index_non_nan = min(col_x.last_valid_index(), col_y.last_valid_index())
        tracer_et_sauvegarder_graphique(col_x[:dernier_index_non_nan + 1], col_y[:dernier_index_non_nan + 1], essai, chemin_figures)

def main():
    CHEMIN_REPERTOIRE = "output"
    chemin_figures = os.path.join(CHEMIN_REPERTOIRE, "figuresEFFORT")
    creer_repertoire(chemin_figures)

    plages_essais = [
        (1, 7), (11, 17), (21, 27), (31, 37),
        (41, 47), (51, 57), (61, 67), (71, 77),
        (81, 87), (91, 97), (101, 107), (111, 117),
        (121, 127), (151, 157),
        (161, 167),
        (171, 177),
        (181, 184),
    ]
    

    essai_vide = "essaiàvide.csv"
    nom_fichier_vide = os.path.join("ACQUISITION FORGEAGE", essai_vide)
    traiter_essai_a_vide(nom_fichier_vide, "Essai Vide", chemin_figures)

    for debut, fin in plages_essais:
        for essai in range(debut, fin + 1):
            if essai == 113:
                continue
            nom_fichier = os.path.join("ACQUISITION FORGEAGE", f"ESSAI_{str(essai).zfill(3)}.csv")
            print(f"Traitement de {nom_fichier}")
            df_essai = charger_donnees(nom_fichier)
            if df_essai is not None:
                traiter_fichier(df_essai, essai, chemin_figures)

    print("Les graphiques ont été générés avec succès.")

if __name__ == "__main__":
    main()
# Out:
# FileNotFoundError: ACQUISITION FORGEAGE\essaiàvide.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_001.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_002.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_003.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_004.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_005.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_006.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_007.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_011.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_012.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_013.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_014.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_015.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_016.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_017.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_021.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_022.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_023.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_024.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_025.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_026.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_027.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_031.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_032.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_033.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_034.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_035.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_036.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_037.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_041.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_042.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_043.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_044.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_045.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_046.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_047.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_051.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_052.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_053.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_054.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_055.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_056.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_057.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_061.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_062.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_063.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_064.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_065.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_066.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_067.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_067.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_071.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_071.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_072.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_072.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_073.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_073.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_074.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_074.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_075.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_075.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_076.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_076.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_077.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_077.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_081.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_081.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_082.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_082.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_083.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_083.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_084.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_084.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_085.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_085.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_086.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_086.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_087.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_087.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_091.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_091.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_092.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_092.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_093.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_093.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_094.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_094.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_095.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_095.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_096.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_096.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_097.csv
# FileNotFoundError: ACQUISITION FORGEAGE\ESSAI_097.csv n'a pas été trouvé.
# Traitement de ACQUISITION FORGEAGE\ESSAI_101.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_102.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_103.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_104.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_105.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_106.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_107.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_111.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_112.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_114.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_115.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_116.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_117.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_121.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_122.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_123.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_124.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_125.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_126.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_127.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_151.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_152.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_153.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_154.csv
# Le fichier ESSAI_154.csv n'a pas assez de colonnes.
# Traitement de ACQUISITION FORGEAGE\ESSAI_155.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_156.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_157.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_161.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_162.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_163.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_164.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_165.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_166.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_167.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_171.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_172.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_173.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_174.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_175.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_176.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_177.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_181.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_182.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_183.csv
# Traitement de ACQUISITION FORGEAGE\ESSAI_184.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 102
#      99     print("Les graphiques ont été générés avec succès.")
#     101 if __name__ == "__main__":
# --> 102     main()
#
# Cell In[2], line 97, in main()
#      95         df_essai = charger_donnees(nom_fichier)
#      96         if df_essai is not None:
# ---> 97             traiter_fichier(df_essai, essai, chemin_figures)
#      99 print("Les graphiques ont été générés avec succès.")
#
# Cell In[2], line 46, in traiter_fichier(df, essai, chemin_figures)
#      43     print(f"Le fichier ESSAI_{str(essai).zfill(3)}.csv n'a pas assez de colonnes.")
#      44     return
# ---> 46 dernier_index_non_nan = min(col_x.last_valid_index(), col_y.last_valid_index())
#      47 tracer_et_sauvegarder_graphique(col_x[:dernier_index_non_nan + 1], col_y[:dernier_index_non_nan + 1], essai, chemin_figures)
#
# TypeError: '<' not supported between instances of 'NoneType' and 'NoneType'
