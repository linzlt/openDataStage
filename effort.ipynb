# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Définir le chemin du répertoire contenant les fichiers de données
CHEMIN_REPERTOIRE = "output"

# Définir le chemin du répertoire pour sauvegarder les figures
chemin_figures = os.path.join(CHEMIN_REPERTOIRE, "figuresEFFORT")

# Vérifier si le répertoire "figures" existe, sinon le créer
if not os.path.exists(chemin_figures):
    os.makedirs(chemin_figures)

# Chemin du fichier CSV contenant les données
FICHIER_AXE_TEMPS = "AXE_DU_TEMPS/ESSAI_1_3_6.csv"
FICHIER_REF_DATA2 = "ACQUISITION FORGEAGE/ESSAI_114.csv"
# Charger les données du fichier CSV
df_axe_temps = pd.read_csv(FICHIER_AXE_TEMPS, delimiter=";")

# Sélectionner la dernière colonne "tps" comme axe du temps
axe_temps = df_axe_temps["tps"]

# Enregistrer l'axe du temps dans un nouveau fichier CSV
axe_temps.to_csv("AXE_DU_TEMPS/AXE_TEMPS.csv", index=False)

fichiers_non_coherents = []

# Récupérer les colonnes de référence pour chaque type de fichier
colonnes_reference1 = pd.read_csv(
    FICHIER_AXE_TEMPS, delimiter=";", nrows=0
).columns.tolist()
colonnes_reference2 = pd.read_csv(
    FICHIER_REF_DATA2, delimiter=";", nrows=0
).columns.tolist()

# Définir les plages d'essais selon la séquence spécifiée
plages_essais = [
    (1, 7), (11, 17), (21, 27), (31, 37),
    (41, 47),
    (51, 57),
    (61, 67),
    (71, 77),
    (81, 87),
    (91, 97),
    (101, 107),
    (111, 117),
    (121, 127),
]

for plage in plages_essais:
    debut, fin = plage
    for essai in range(debut, fin + 1):
        if essai == 113:
            continue
        # Construire le chemin complet du fichier CSV de l'essai
        nom_fichier = os.path.join(
            "ACQUISITION FORGEAGE", f"ESSAI_{str(essai).zfill(3)}.csv"
        )
        print(nom_fichier)
        print(os.getcwd())
        if os.path.exists(nom_fichier):
            print("exist")
            try:
                # Charger les données à partir du fichier CSV de l'essai
                df_essai = pd.read_csv(nom_fichier, delimiter=";", skiprows=0)

                # Vérifier que les colonnes 2 et 9 existent
                if df_essai.shape[1] > 8:
                    # Conversion des données en float
                    for col in df_essai.columns:
                        if df_essai[col].dtype == "object":
                            df_essai[col] = df_essai[col].str.replace(",", ".").astype(float)
                        elif df_essai[col].dtype == "float64" and df_essai[col].isnull().any():
                            df_essai[col] = df_essai[col].astype(float)
                    # OFFSET     
                    if df_essai.shape[1] > 8:
                        df_essai.iloc[:, 8] = df_essai.iloc[:, 8] - df_essai.iloc[0, 8]
                    # Sélectionner les colonnes 2 et 9
                    col2 = df_essai.iloc[:, 1]
                    col9 = df_essai.iloc[:, 8]

                    # Trouver l'indice de la dernière valeur non NaN commune aux deux colonnes
                    dernier_index_non_nan = min(col2.last_valid_index(), col9.last_valid_index())

                    # Tronquer les colonnes pour qu'elles aient la même taille
                    col2_tronque = col2[:dernier_index_non_nan + 1]
                    col9_tronque = col9[:dernier_index_non_nan + 1]

                    # Tracer la colonne 2 en fonction de la colonne 9
                    plt.plot(col9_tronque, col2_tronque, label=f'Essai {essai}')

                    # Ajouter des titres et des légendes
                    plt.title(f"Essai {essai}")
                    plt.xlabel("Deplacement")
                    plt.ylabel("Effort")
                    plt.legend(loc="upper right")

                    # Afficher et sauvegarder le graphique dans le dossier "figures"
                    plt.grid(True)
                    nom_figure = os.path.join(chemin_figures, f"ESSAI_{str(essai).zfill(3)}.png")
                    plt.savefig(nom_figure)
                    plt.close()
                else:
                    print(f"Le fichier {nom_fichier} n'a pas assez de colonnes.")
            except FileNotFoundError:
                print("FileNotFoundError")
                continue  # Passer à l'essai suivant s'il n'y a pas de fichier pour cet essai

print("Les graphiques ont été générés avec succès.")
# Out:
# ACQUISITION FORGEAGE\ESSAI_001.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_002.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_003.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_004.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_005.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_006.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_007.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_011.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_012.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_013.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_014.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_015.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_016.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_017.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_021.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_022.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_023.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_024.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_025.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_026.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_027.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_031.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_032.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_033.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_034.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_035.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_036.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_037.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_041.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_042.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_043.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_044.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_045.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_046.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_047.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_051.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_052.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_053.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_054.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_055.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_056.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_057.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_061.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_062.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_063.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_064.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_065.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_066.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# ACQUISITION FORGEAGE\ESSAI_067.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_071.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_072.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_073.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_074.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_075.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_076.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_077.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_081.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_082.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_083.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_084.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_085.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_086.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_087.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_091.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_092.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_093.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_094.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_095.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_096.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_097.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# ACQUISITION FORGEAGE\ESSAI_101.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_101.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_102.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_102.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_103.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_103.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_104.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_104.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_105.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_105.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_106.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_106.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_107.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_107.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_111.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_111.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_112.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_112.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_114.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_114.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_115.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_115.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_116.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_116.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_117.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_117.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_121.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_121.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_122.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_122.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_123.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_123.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_124.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_124.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_125.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_125.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_126.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_126.csv n'a pas assez de colonnes.
# ACQUISITION FORGEAGE\ESSAI_127.csv
# c:\Users\linaz\OneDrive\Bureau\StageOpenData-main
# exist
# Le fichier ACQUISITION FORGEAGE\ESSAI_127.csv n'a pas assez de colonnes.
# Les graphiques ont été générés avec succès.
